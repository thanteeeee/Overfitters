# %%
# %pip install pandas 
# %pip install openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\title\appdata\local\programs\python\python311\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\title\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\title\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\title\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\title\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: openpyxl in c:\users\title\appdata\local\programs\python\python311\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\title\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
kagglepath =  "../../dataset/kgdataset.csv"
surveypath = "../../dataset/survey_data.xlsx"
df = pd.read_csv(kagglepath)
df2 = pd.read_excel(surveypath)

# %%
df2.drop(df2.columns[0],axis=1, inplace=True)

# %%
df2.columns = df.columns

# %%
combined = pd.concat([df, df2], ignore_index=True)
combined
# Out:
#      Age Sleep Hours Feel Rested Daily Screen Time Use Before Sleep  \
# 0     47           4         Yes                11              Yes
# 1     48           4          No                 8               No
# 2     40           7   Sometimes                10               No
# 3     26          10         Yes                 5              Yes
# 4     47           5         Yes                 7              Yes
# ...   ..         ...         ...               ...              ...
# 1181  21          10      สดชื่น                 8              ใช่
# 1182  17         7-8   ไม่สดชื่น             >8ชม.              ใช่
# 1183  17         6-8      สดชื่น               3-4              ใช่
# 1184  17           6   ไม่สดชื่น                 4              ใช่
# 1185  16           8      สดชื่น                 8              ใช่
#
#       Stress Level          Anxiety/Low Mood Wellness Apps Sleep Quality  \
# 0               10                        No            No           Bad
# 1                7                       Yes           Yes           Bad
# 2                4                        No           Yes           Bad
# 3                1                       Yes            No          Good
# 4                7                       Yes            No          Good
# ...            ...                       ...           ...           ...
# 1181             4  ไม่หงุดหงิด/ไม่วิตกกังวล           ใช่            ดี
# 1182             8  ไม่หงุดหงิด/ไม่วิตกกังวล        ไม่ใช่            ดี
# 1183             6  ไม่หงุดหงิด/ไม่วิตกกังวล           ใช่         ไม่ดี
# 1184             6  ไม่หงุดหงิด/ไม่วิตกกังวล        ไม่ใช่         ไม่ดี
# 1185             1  ไม่หงุดหงิด/ไม่วิตกกังวล        ไม่ใช่            ดี
#
#      Screen Time Affects Sleep?
# 0                           Yes
# 1                           Yes
# 2                           Yes
# 3                            No
# 4                           Yes
# ...                         ...
# 1181                   ไม่แน่ใจ
# 1182                   ไม่แน่ใจ
# 1183                        ใช่
# 1184                        ใช่
# 1185                        ใช่
#
# [1186 rows x 10 columns]
